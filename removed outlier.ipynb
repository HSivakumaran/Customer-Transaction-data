# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv('QVI_transaction_data.csv')

# %%
dataset.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %%
dataset.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %%
dataset.shape
# Out:
# (264836, 8)

# %%
dataset['TXN_ID'].nunique()
# Out:
# 263127

# %%
dataset[dataset.duplicated(['TXN_ID'])].head()
# Out:
#       DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 42   43605         55           55073   48887       113
# 377  43475          7            7364    7739        20
# 419  43391         12           12301   10982        93
# 476  43351         16           16427   14546        81
# 511  43315         19           19272   16683        31
#
#                                    PROD_NAME  PROD_QTY  TOT_SALES
# 42                      Twisties Chicken270g         1        4.6
# 377         Doritos Cheese      Supreme 330g         2       11.4
# 419  Doritos Corn Chip Southern Chicken 150g         2        7.8
# 476          Pringles Original   Crisps 134g         1        3.7
# 511   Infzns Crn Crnchers Tangy Gcamole 110g         2        7.6

# %%
dataset.loc[dataset['TXN_ID']==48887,:]
# Out:
#      DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 41  43605         55           55073   48887         4
# 42  43605         55           55073   48887       113
#
#                            PROD_NAME  PROD_QTY  TOT_SALES
# 41  Dorito Corn Chp     Supreme 380g         1       3.25
# 42              Twisties Chicken270g         1       4.60

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
import datetime
from matplotlib.dates import DateFormatter

# %%
def xlseriesdate_to_datetime(xlserialdate):
    excel_anchor = datetime.datetime(1900, 1, 1)
    if(xlserialdate < 60):
        delta_in_days = datetime.timedelta(days = (xlserialdate - 1))
    else:
        delta_in_days = datetime.timedelta(days = (xlserialdate - 2))
    converted_date = excel_anchor + delta_in_days
    return converted_date

# %%
dataset['DATE'] = dataset['DATE'].apply(xlseriesdate_to_datetime)

# %%
dataset['DATE'].head()
# Out:
# 0   2018-10-17
# 1   2019-05-14
# 2   2019-05-20
# 3   2018-08-17
# 4   2018-08-18
# Name: DATE, dtype: datetime64[ns]

# %%
dataset.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %%
dataset['PROD_NAME'].head()
# Out:
# 0      Natural Chip        Compny SeaSalt175g
# 1                    CCs Nacho Cheese    175g
# 2      Smiths Crinkle Cut  Chips Chicken 170g
# 3      Smiths Chip Thinly  S/Cream&Onion 175g
# 4    Kettle Tortilla ChpsHny&Jlpno Chili 150g
# Name: PROD_NAME, dtype: object

# %%
dataset['PACK_SIZE'] = dataset['PROD_NAME'].str.extract("(\d+)")
dataset['PACK_SIZE'] = pd.to_numeric(dataset['PACK_SIZE'])
dataset.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE
# 0    Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1                  CCs Nacho Cheese    175g         3        6.3        175
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9        170
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0        175
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8        150

# %%
import re

# %%
def clean_text(text):
    text = re.sub('[&/]', ' ', text) 
    text = re.sub('\d\w*', ' ', text) 
    return text

dataset['PROD_NAME'] = dataset['PROD_NAME'].apply(clean_text)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist as fdist
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hsiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
cleanProdName = dataset['PROD_NAME']
string = ''.join(cleanProdName)
prodWord = word_tokenize(string)

# %%
wordFrequency = fdist(prodWord)
freq_df = pd.DataFrame(list(wordFrequency.items()), columns = ["Word", "Frequency"]).sort_values(by = 'Frequency', ascending = False)

# %%
freq_df.head()
# Out:
#         Word  Frequency
# 10     Chips      49770
# 16    Kettle      40739
# 7     Smiths      28572
# 6     Cheese      27890
# 66  Pringles      24743

# %%
dataset['PROD_NAME'] = dataset['PROD_NAME'].apply(lambda x: x.lower())
dataset = dataset[~dataset['PROD_NAME'].str.contains("salsa")]
dataset['PROD_NAME'] = dataset['PROD_NAME'].apply(lambda x: x.title())

# %%
dataset.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                                PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE
# 0    Natural Chip        Compny Seasalt          2        6.0        175
# 1                  Ccs Nacho Cheese              3        6.3        175
# 2    Smiths Crinkle Cut  Chips Chicken           2        2.9        170
# 3    Smiths Chip Thinly  S Cream Onion           5       15.0        175
# 4  Kettle Tortilla Chpshny Jlpno Chili           3       13.8        150

# %%
dataset['PROD_QTY'].value_counts()
# Out:
# 2      220070
# 1       25476
# 5         415
# 3         408
# 4         371
# 200         2
# Name: PROD_QTY, dtype: int64

# %%
dataset.loc[dataset['PROD_QTY'] == 200,:]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                            PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE
# 69762  Dorito Corn Chp     Supreme         200      650.0        380
# 69763  Dorito Corn Chp     Supreme         200      650.0        380

# %%
dataset.loc[dataset['LYLTY_CARD_NBR'] == 226000, :]
# Out:
#             DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19        226          226000  226201         4
# 69763 2019-05-20        226          226000  226210         4
#
#                            PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE
# 69762  Dorito Corn Chp     Supreme         200      650.0        380
# 69763  Dorito Corn Chp     Supreme         200      650.0        380

# %%
dataset.drop(dataset.index[dataset['LYLTY_CARD_NBR'] == 226000], inplace = True)

# %%
dataset.loc[dataset['LYLTY_CARD_NBR'] == 226000]
# Out:
# Empty DataFrame
# Columns: [DATE, STORE_NBR, LYLTY_CARD_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PACK_SIZE]
# Index: []
